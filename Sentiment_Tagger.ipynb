# %% [markdown]
# # Sentiment Analysis and Emotion Detection

# %% [markdown]
# #### Installing Dependencies

# %%
# !pip install pandas torch transformers nltk
# Out:
# Requirement already satisfied: pandas in c:\anaconda\lib\site-packages (2.2.3)
# Requirement already satisfied: torch in c:\anaconda\lib\site-packages (2.7.1)
# Requirement already satisfied: transformers in c:\anaconda\lib\site-packages (4.53.3)
# Requirement already satisfied: nltk in c:\anaconda\lib\site-packages (3.9.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\anaconda\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\anaconda\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\anaconda\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\anaconda\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\anaconda\lib\site-packages (from transformers) (0.33.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\anaconda\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\anaconda\lib\site-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: click in c:\anaconda\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\anaconda\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->transformers) (2025.4.26)

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import nltk
import re
import torch.nn.functional as F
nltk.download("punkt")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Talha
# [nltk_data]     Malik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### Loading Models

# %%
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment-latest",
    tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest",
    device=0 if torch.cuda.is_available() else -1
)

# Emotion model (BERT GoEmotions)
emotion_model_name = "bhadresh-savani/bert-base-go-emotion"
emotion_tokenizer = AutoTokenizer.from_pretrained(emotion_model_name)
emotion_model = AutoModelForSequenceClassification.from_pretrained(emotion_model_name).to(device)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu

# %% [markdown]
# #### Processing

# %%
# Sentiment labels (Twitter RoBERTa)
sentiment_labels = {
    "LABEL_0": "😡 Negative",
    "LABEL_1": "😐 Neutral",
    "LABEL_2": "😄 Positive"
}


# ----------------------------------
# 2. Helper functions
# ----------------------------------
def predict_emotion(text):
    inputs = emotion_tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)
    with torch.no_grad():
        outputs = emotion_model(**inputs)
    probs = F.softmax(outputs.logits, dim=1)
    top_prob, top_class = torch.topk(probs, 1)
    label = emotion_model.config.id2label[top_class.item()]
    return label, top_prob.item()

def paragraph_to_phrases(paragraph):
    sentences = nltk.sent_tokenize(paragraph)
    phrases = []
    for sentence in sentences:
        parts = re.split(r',|;|\band\b|\bbut\b|\bor\b|\bso\b|\byet\b', sentence, flags=re.IGNORECASE)
        parts = [p.strip() for p in parts if p.strip()]
        phrases.extend(parts)
    return phrases

# ----------------------------------
# 3. Read CSV
# ----------------------------------
df = pd.read_csv("1000paragraphs.csv")  # must have column 'paragraphs'

# ----------------------------------
# 4. Processing
# ----------------------------------
for i, paragraph in enumerate(df["paragraph"], start=1):
    paragraph = str(paragraph).strip()
    if not paragraph:
        continue

    print(f"\n📄 Paragraph {i}:\n{paragraph}")

    # ----- Paragraph-level Sentiment -----
    para_sent = sentiment_pipeline(paragraph)[0]
    pretty_sent_label = sentiment_labels.get(para_sent["label"], para_sent["label"])

    # ----- Paragraph-level Emotion -----
    para_emotion, para_emotion_conf = predict_emotion(paragraph)

    print(f"\n📊 Overall Paragraph Sentiment ➤ {pretty_sent_label} (Confidence: {para_sent['score']:.2f})")
    print(f"🎭 Overall Paragraph Emotion ➤ {para_emotion} (Confidence: {para_emotion_conf:.2f})\n")

    # ----- Phrase-level Analysis -----
    phrases = paragraph_to_phrases(paragraph)
    for idx, phrase in enumerate(phrases, start=1):
        phrase_sent = sentiment_pipeline(phrase)[0]
        pretty_phrase_label = sentiment_labels.get(phrase_sent["label"], phrase_sent["label"])
        phrase_emotion, phrase_emotion_conf = predict_emotion(phrase)

        print(f"✂️ Phrase {idx}: {phrase}")
        print(f"   ➤ Sentiment: {pretty_phrase_label} (Confidence: {phrase_sent['score']:.2f})")
        print(f"   ➤ Emotion:   {phrase_emotion} (Confidence: {phrase_emotion_conf:.2f})\n")
# Out:
# 📄 Paragraph 1:
# Dr. Amelia Hart, a brilliant astrophysicist, was the lead scientist at CREA's headquarters on Luna. She had devoted her entire life to understanding the mysteries of the universe and had become a pioneer in her field. She was determined to uncover the secrets of the cosmic rifts, a series of mysterious and seemingly unconnected energy anomalies that had started appearing throughout the galaxy.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.86)
# 🎭 Overall Paragraph Emotion ➤ admiration (Confidence: 0.46)
#
# ✂️ Phrase 1: Dr. Amelia Hart
#    ➤ Sentiment: neutral (Confidence: 0.82)
#    ➤ Emotion:   admiration (Confidence: 0.34)
#
# ✂️ Phrase 2: a brilliant astrophysicist
#    ➤ Sentiment: positive (Confidence: 0.95)
#    ➤ Emotion:   admiration (Confidence: 0.85)
#
# ✂️ Phrase 3: was the lead scientist at CREA's headquarters on Luna.
#    ➤ Sentiment: neutral (Confidence: 0.93)
#    ➤ Emotion:   neutral (Confidence: 0.58)
#
# ✂️ Phrase 4: She had devoted her entire life to understanding the mysteries of the universe
#    ➤ Sentiment: positive (Confidence: 0.59)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 5: had become a pioneer in her field.
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 6: She was determined to uncover the secrets of the cosmic rifts
#    ➤ Sentiment: positive (Confidence: 0.53)
#    ➤ Emotion:   neutral (Confidence: 0.46)
#
# ✂️ Phrase 7: a series of mysterious
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 8: seemingly unconnected energy anomalies that had started appearing throughout the galaxy.
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.40)
#
#
# 📄 Paragraph 2:
# Dr. Hart assembled a diverse team of experts for her next mission, including her trusted second-in-command, Captain John "Jack" Reynolds, a seasoned astronaut and veteran of numerous CREA expeditions; Dr. Evelyn "Eve" Turner, a talented botanist and biologist; and Dr. Arthur "Art" Simmons, a genius engineer and inventor. Together, they would embark on a journey to explore the cosmic rift located in the Orion Arm of the Milky Way.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.63)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.75)
#
# ✂️ Phrase 1: Dr. Hart assembled a diverse team of experts for her next mission
#    ➤ Sentiment: positive (Confidence: 0.67)
#    ➤ Emotion:   neutral (Confidence: 0.37)
#
# ✂️ Phrase 2: including her trusted second-in-command
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.80)
#
# ✂️ Phrase 3: Captain John "Jack" Reynolds
#    ➤ Sentiment: neutral (Confidence: 0.82)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 4: a seasoned astronaut
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 5: veteran of numerous CREA expeditions
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 6: Dr. Evelyn "Eve" Turner
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.90)
#
# ✂️ Phrase 7: a talented botanist
#    ➤ Sentiment: positive (Confidence: 0.94)
#    ➤ Emotion:   admiration (Confidence: 0.69)
#
# ✂️ Phrase 8: biologist
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 9: Dr. Arthur "Art" Simmons
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 10: a genius engineer
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   admiration (Confidence: 0.79)
#
# ✂️ Phrase 11: inventor.
#    ➤ Sentiment: neutral (Confidence: 0.74)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
# ✂️ Phrase 12: Together
#    ➤ Sentiment: positive (Confidence: 0.56)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
# ✂️ Phrase 13: they would embark on a journey to explore the cosmic rift located in the Orion Arm of the Milky Way.
#    ➤ Sentiment: neutral (Confidence: 0.92)
#    ➤ Emotion:   neutral (Confidence: 0.43)
#
#
# 📄 Paragraph 3:
# Their spacecraft, the SS Excelsior, was equipped with the latest technology, including a state-of-the-art cloaking device that would allow them to remain undetected as they ventured deeper into uncharted territory. As the Excelsior left the safety of Luna's orbit, the crew was filled with anticipation and excitement. Little did they know that their journey would lead them to the edge of the known universe and beyond.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.86)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.82)
#
# ✂️ Phrase 1: Their spacecraft
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 2: the SS Excelsior
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.49)
#
# ✂️ Phrase 3: was equipped with the latest technology
#    ➤ Sentiment: neutral (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.64)
#
# ✂️ Phrase 4: including a state-of-the-art cloaking device that would allow them to remain undetected as they ventured deeper into uncharted territory.
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.71)
#
# ✂️ Phrase 5: As the Excelsior left the safety of Luna's orbit
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.43)
#
# ✂️ Phrase 6: the crew was filled with anticipation
#    ➤ Sentiment: positive (Confidence: 0.96)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 7: excitement.
#    ➤ Sentiment: positive (Confidence: 0.75)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 8: Little did they know that their journey would lead them to the edge of the known universe
#    ➤ Sentiment: neutral (Confidence: 0.67)
#    ➤ Emotion:   neutral (Confidence: 0.45)
#
# ✂️ Phrase 9: beyond.
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
#
# 📄 Paragraph 4:
# As they approached the cosmic rift, the Excelsior was suddenly engulfed by a powerful energy wave that shook the ship to its core. The crew struggled to maintain control, but the rift's energy began to interfere with their systems. Just as the Excelsior was on the verge of being torn apart, Dr. Simmons managed to activate the ship's emergency cloaking device. The rift's energy pulsed around the Excelsior, but the ship remained hidden, protected by its advanced technology.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.52)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.72)
#
# ✂️ Phrase 1: As they approached the cosmic rift
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.86)
#
# ✂️ Phrase 2: the Excelsior was suddenly engulfed by a powerful energy wave that shook the ship to its core.
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.28)
#
# ✂️ Phrase 3: The crew struggled to maintain control
#    ➤ Sentiment: negative (Confidence: 0.64)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 4: the rift's energy began to interfere with their systems.
#    ➤ Sentiment: negative (Confidence: 0.63)
#    ➤ Emotion:   neutral (Confidence: 0.75)
#
# ✂️ Phrase 5: Just as the Excelsior was on the verge of being torn apart
#    ➤ Sentiment: negative (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.42)
#
# ✂️ Phrase 6: Dr. Simmons managed to activate the ship's emergency cloaking device.
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 7: The rift's energy pulsed around the Excelsior
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.31)
#
# ✂️ Phrase 8: the ship remained hidden
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 9: protected by its advanced technology.
#    ➤ Sentiment: positive (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
#
# 📄 Paragraph 5:
# With their ship safely concealed, Dr. Hart and her team decided to send an exploration pod through the rift. As they ventured deeper into the unknown, they discovered a vast, twisted nebula filled with unimaginable wonders and dangers. They encountered alien life forms, exotic planets, and ancient artifacts that hinted at a long-lost civilization that had once ruled the galaxy.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.80)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.75)
#
# ✂️ Phrase 1: With their ship safely concealed
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 2: Dr. Hart
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 3: her team decided to send an exploration pod through the rift.
#    ➤ Sentiment: neutral (Confidence: 0.94)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 4: As they ventured deeper into the unknown
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 5: they discovered a vast
#    ➤ Sentiment: neutral (Confidence: 0.57)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 6: twisted nebula filled with unimaginable wonders
#    ➤ Sentiment: positive (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.39)
#
# ✂️ Phrase 7: dangers.
#    ➤ Sentiment: negative (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 8: They encountered alien life forms
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 9: exotic planets
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 10: ancient artifacts that hinted at a long-lost civilization that had once ruled the galaxy.
#    ➤ Sentiment: neutral (Confidence: 0.90)
#    ➤ Emotion:   neutral (Confidence: 0.38)
#
#
# 📄 Paragraph 6:
# Their journey took a dark turn when they encountered the malevolent and powerful entity known as the Enigma. This cosmic being, a creature of pure energy and malevolence, had been responsible for the creation of the cosmic rifts in an attempt to conquer the galaxy and enslave its inhabitants. The Enigma had been lurking in the shadows for millennia, feeding on the suffering and despair of its victims, and growing stronger with each passing moment.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.83)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.35)
#
# ✂️ Phrase 1: Their journey took a dark turn when they encountered the malevolent
#    ➤ Sentiment: negative (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.35)
#
# ✂️ Phrase 2: powerful entity known as the Enigma.
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 3: This cosmic being
#    ➤ Sentiment: neutral (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.26)
#
# ✂️ Phrase 4: a creature of pure energy
#    ➤ Sentiment: positive (Confidence: 0.86)
#    ➤ Emotion:   neutral (Confidence: 0.36)
#
# ✂️ Phrase 5: malevolence
#    ➤ Sentiment: negative (Confidence: 0.52)
#    ➤ Emotion:   sadness (Confidence: 0.46)
#
# ✂️ Phrase 6: had been responsible for the creation of the cosmic rifts in an attempt to conquer the galaxy
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.33)
#
# ✂️ Phrase 7: enslave its inhabitants.
#    ➤ Sentiment: neutral (Confidence: 0.62)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 8: The Enigma had been lurking in the shadows for millennia
#    ➤ Sentiment: negative (Confidence: 0.53)
#    ➤ Emotion:   neutral (Confidence: 0.70)
#
# ✂️ Phrase 9: feeding on the suffering
#    ➤ Sentiment: negative (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.35)
#
# ✂️ Phrase 10: despair of its victims
#    ➤ Sentiment: negative (Confidence: 0.84)
#    ➤ Emotion:   sadness (Confidence: 0.28)
#
# ✂️ Phrase 11: growing stronger with each passing moment.
#    ➤ Sentiment: positive (Confidence: 0.92)
#    ➤ Emotion:   neutral (Confidence: 0.35)
#
#
# 📄 Paragraph 7:
# As the crew of the Excelsior continued their exploration, they realized that they were not just uncovering the secrets of the cosmic rifts but also becoming entangled in the Enigma's sinister plans. The Enigma had foreseen their arrival and had been manipulating their every move, using the crew's own discoveries to its advantage. The more they learned about the cosmic rifts and the Enigma's nefarious deeds, the more they became pawns in the Enigma's twisted game.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.65)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.39)
#
# ✂️ Phrase 1: As the crew of the Excelsior continued their exploration
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 2: they realized that they were not just uncovering the secrets of the cosmic rifts
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.23)
#
# ✂️ Phrase 3: also becoming entangled in the Enigma's sinister plans.
#    ➤ Sentiment: neutral (Confidence: 0.60)
#    ➤ Emotion:   neutral (Confidence: 0.62)
#
# ✂️ Phrase 4: The Enigma had foreseen their arrival
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 5: had been manipulating their every move
#    ➤ Sentiment: neutral (Confidence: 0.51)
#    ➤ Emotion:   neutral (Confidence: 0.77)
#
# ✂️ Phrase 6: using the crew's own discoveries to its advantage.
#    ➤ Sentiment: neutral (Confidence: 0.78)
#    ➤ Emotion:   neutral (Confidence: 0.84)
#
# ✂️ Phrase 7: The more they learned about the cosmic rifts
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 8: the Enigma's nefarious deeds
#    ➤ Sentiment: negative (Confidence: 0.50)
#    ➤ Emotion:   neutral (Confidence: 0.46)
#
# ✂️ Phrase 9: the more they became pawns in the Enigma's twisted game.
#    ➤ Sentiment: negative (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
#
# 📄 Paragraph 8:
# Captain Reynolds, Dr. Hart, Dr. Turner, and Dr. Simmons would soon find themselves in a desperate struggle against the Enigma and its minions. They would face insurmountable odds and make sacrifices beyond imagination as they sought to save not only themselves but the entire galaxy from the Enigma's tyrannical rule.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.58)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.81)
#
# ✂️ Phrase 1: Captain Reynolds
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 2: Dr. Hart
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 3: Dr. Turner
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.97)
#
# ✂️ Phrase 4: Dr. Simmons would soon find themselves in a desperate struggle against the Enigma
#    ➤ Sentiment: negative (Confidence: 0.54)
#    ➤ Emotion:   neutral (Confidence: 0.37)
#
# ✂️ Phrase 5: its minions.
#    ➤ Sentiment: negative (Confidence: 0.57)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 6: They would face insurmountable odds
#    ➤ Sentiment: negative (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.64)
#
# ✂️ Phrase 7: make sacrifices beyond imagination as they sought to save not only themselves
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   neutral (Confidence: 0.71)
#
# ✂️ Phrase 8: the entire galaxy from the Enigma's tyrannical rule.
#    ➤ Sentiment: negative (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.50)
#
#
# 📄 Paragraph 9:
# As the crew of the Excelsior fought valiantly against the Enigma's forces, Dr. Hart made a stunning discovery. She uncovered a hidden prophecy that spoke of a hero who would rise to defeat the Enigma and restore balance to the universe. This hero, the prophecy revealed, would be born from the union of two powerful beings, one from Earth and one from the stars.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.72)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.56)
#
# ✂️ Phrase 1: As the crew of the Excelsior fought valiantly against the Enigma's forces
#    ➤ Sentiment: positive (Confidence: 0.53)
#    ➤ Emotion:   neutral (Confidence: 0.25)
#
# ✂️ Phrase 2: Dr. Hart made a stunning discovery.
#    ➤ Sentiment: positive (Confidence: 0.98)
#    ➤ Emotion:   admiration (Confidence: 0.87)
#
# ✂️ Phrase 3: She uncovered a hidden prophecy that spoke of a hero who would rise to defeat the Enigma
#    ➤ Sentiment: neutral (Confidence: 0.66)
#    ➤ Emotion:   neutral (Confidence: 0.31)
#
# ✂️ Phrase 4: restore balance to the universe.
#    ➤ Sentiment: neutral (Confidence: 0.62)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 5: This hero
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   admiration (Confidence: 0.83)
#
# ✂️ Phrase 6: the prophecy revealed
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 7: would be born from the union of two powerful beings
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 8: one from Earth
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 9: one from the stars.
#    ➤ Sentiment: neutral (Confidence: 0.64)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
#
# 📄 Paragraph 10:
# With this newfound knowledge, Dr. Hart and her team set out to locate the two beings who would become the parents of the prophesized hero. As they traversed the cosmic rift, they discovered that the Enigma had anticipated their actions and had already begun to hunt down the potential parents.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.82)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.87)
#
# ✂️ Phrase 1: With this newfound knowledge
#    ➤ Sentiment: positive (Confidence: 0.64)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 2: Dr. Hart
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 3: her team set out to locate the two beings who would become the parents of the prophesized hero.
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.57)
#
# ✂️ Phrase 4: As they traversed the cosmic rift
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.80)
#
# ✂️ Phrase 5: they discovered that the Enigma had anticipated their actions
#    ➤ Sentiment: neutral (Confidence: 0.92)
#    ➤ Emotion:   neutral (Confidence: 0.61)
#
# ✂️ Phrase 6: had already begun to hunt down the potential parents.
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.41)
#
#
# 📄 Paragraph 11:
# In a race against time, the crew of the Excelsior fought their way through the Enigma's minions and protected the would-be parents at all costs. As they journeyed deeper into the rift, they found themselves confronted by the full might of the Enigma's forces, including its deadly guardian, the Shadowbeast.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.77)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.88)
#
# ✂️ Phrase 1: In a race against time
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 2: the crew of the Excelsior fought their way through the Enigma's minions
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.36)
#
# ✂️ Phrase 3: protected the would-be parents at all costs.
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 4: As they journeyed deeper into the rift
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   approval (Confidence: 0.32)
#
# ✂️ Phrase 5: they found themselves confronted by the full might of the Enigma's forces
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.77)
#
# ✂️ Phrase 6: including its deadly guardian
#    ➤ Sentiment: negative (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 7: the Shadowbeast.
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
#
# 📄 Paragraph 12:
# The Shadowbeast, a monstrous creature of pure energy and darkness, was a formidable foe that could tear apart planets and consume entire star systems. As the Excelsior and its crew faced off against the terrifying beast, they realized that they would need to combine their talents and resources in order to stand a chance against such an overwhelming adversary.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.69)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.51)
#
# ✂️ Phrase 1: The Shadowbeast
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 2: a monstrous creature of pure energy
#    ➤ Sentiment: negative (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.55)
#
# ✂️ Phrase 3: darkness
#    ➤ Sentiment: negative (Confidence: 0.64)
#    ➤ Emotion:   neutral (Confidence: 0.97)
#
# ✂️ Phrase 4: was a formidable foe that could tear apart planets
#    ➤ Sentiment: neutral (Confidence: 0.48)
#    ➤ Emotion:   neutral (Confidence: 0.48)
#
# ✂️ Phrase 5: consume entire star systems.
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.97)
#
# ✂️ Phrase 6: As the Excelsior
#    ➤ Sentiment: neutral (Confidence: 0.50)
#    ➤ Emotion:   neutral (Confidence: 0.54)
#
# ✂️ Phrase 7: its crew faced off against the terrifying beast
#    ➤ Sentiment: neutral (Confidence: 0.52)
#    ➤ Emotion:   fear (Confidence: 0.76)
#
# ✂️ Phrase 8: they realized that they would need to combine their talents
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.26)
#
# ✂️ Phrase 9: resources in order to stand a chance against such an overwhelming adversary.
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   approval (Confidence: 0.40)
#
#
# 📄 Paragraph 13:
# Dr. Hart, Dr. Turner, and Dr. Simmons devised a plan to outsmart the Enigma and its minions. They would use the SS Excelsior's advanced technology to create a powerful weapon that could not only destroy the Shadowbeast but also sever the Enigma's connection to the cosmic rift.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.80)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.79)
#
# ✂️ Phrase 1: Dr. Hart
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 2: Dr. Turner
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.97)
#
# ✂️ Phrase 3: Dr. Simmons devised a plan to outsmart the Enigma
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 4: its minions.
#    ➤ Sentiment: negative (Confidence: 0.57)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 5: They would use the SS Excelsior's advanced technology to create a powerful weapon that could not only destroy the Shadowbeast
#    ➤ Sentiment: neutral (Confidence: 0.63)
#    ➤ Emotion:   neutral (Confidence: 0.35)
#
# ✂️ Phrase 6: also sever the Enigma's connection to the cosmic rift.
#    ➤ Sentiment: neutral (Confidence: 0.74)
#    ➤ Emotion:   neutral (Confidence: 0.63)
#
#
# 📄 Paragraph 14:
# Captain Reynolds, the indomitable spirit of Earth's pioneering spirit, would lead the crew in a daring assault on the Enigma's stronghold, deep within the heart of the cosmic rift. They would infiltrate the fortress and sabotage its defenses, allowing them to strike a decisive blow against the Enigma and its sinister plans.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.77)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.84)
#
# ✂️ Phrase 1: Captain Reynolds
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 2: the indomitable spirit of Earth's pioneering spirit
#    ➤ Sentiment: positive (Confidence: 0.62)
#    ➤ Emotion:   admiration (Confidence: 0.35)
#
# ✂️ Phrase 3: would lead the crew in a daring assault on the Enigma's stronghold
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.73)
#
# ✂️ Phrase 4: deep within the heart of the cosmic rift.
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.22)
#
# ✂️ Phrase 5: They would infiltrate the fortress
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 6: sabotage its defenses
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 7: allowing them to strike a decisive blow against the Enigma
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 8: its sinister plans.
#    ➤ Sentiment: negative (Confidence: 0.48)
#    ➤ Emotion:   neutral (Confidence: 0.84)
#
#
# 📄 Paragraph 15:
# As they prepared for their final stand, the crew of the Excelsior knew that they were entering the most dangerous and uncertain period of their journey. They would face unimaginable horrors and make choices that would change the course of history. They would become heroes in the face of adversity, fighting for the future of the galaxy and the lives of countless innocents.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.51)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.71)
#
# ✂️ Phrase 1: As they prepared for their final stand
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 2: the crew of the Excelsior knew that they were entering the most dangerous
#    ➤ Sentiment: negative (Confidence: 0.63)
#    ➤ Emotion:   fear (Confidence: 0.29)
#
# ✂️ Phrase 3: uncertain period of their journey.
#    ➤ Sentiment: neutral (Confidence: 0.90)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 4: They would face unimaginable horrors
#    ➤ Sentiment: negative (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.71)
#
# ✂️ Phrase 5: make choices that would change the course of history.
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.42)
#
# ✂️ Phrase 6: They would become heroes in the face of adversity
#    ➤ Sentiment: positive (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.81)
#
# ✂️ Phrase 7: fighting for the future of the galaxy
#    ➤ Sentiment: positive (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.47)
#
# ✂️ Phrase 8: the lives of countless innocents.
#    ➤ Sentiment: negative (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
#
# 📄 Paragraph 16:
# The battle that ensued was one of the most epic and brutal confrontations in the annals of galactic history. The crew of the Excelsior fought valiantly against the Enigma's forces, using their wits, courage, and the power of their advanced technology to turn the tide of the battle.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.58)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.64)
#
# ✂️ Phrase 1: The battle that ensued was one of the most epic
#    ➤ Sentiment: positive (Confidence: 0.96)
#    ➤ Emotion:   neutral (Confidence: 0.41)
#
# ✂️ Phrase 2: brutal confrontations in the annals of galactic history.
#    ➤ Sentiment: negative (Confidence: 0.82)
#    ➤ Emotion:   disgust (Confidence: 0.27)
#
# ✂️ Phrase 3: The crew of the Excelsior fought valiantly against the Enigma's forces
#    ➤ Sentiment: positive (Confidence: 0.66)
#    ➤ Emotion:   neutral (Confidence: 0.22)
#
# ✂️ Phrase 4: using their wits
#    ➤ Sentiment: neutral (Confidence: 0.50)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 5: courage
#    ➤ Sentiment: positive (Confidence: 0.55)
#    ➤ Emotion:   neutral (Confidence: 0.65)
#
# ✂️ Phrase 6: the power of their advanced technology to turn the tide of the battle.
#    ➤ Sentiment: neutral (Confidence: 0.59)
#    ➤ Emotion:   neutral (Confidence: 0.75)
#
#
# 📄 Paragraph 17:
# Captain Reynolds, leading the charge, personally confronted the Shadowbeast in a fierce duel that would determine the fate of the galaxy. As the beast's energy blasts tore through the Excelsior's hull and threatened to consume the ship, Dr. Simmons managed to complete the construction of the weapon and activate its destructive power.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.78)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.87)
#
# ✂️ Phrase 1: Captain Reynolds
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 2: leading the charge
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 3: personally confronted the Shadowbeast in a fierce duel that would determine the fate of the galaxy.
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.70)
#
# ✂️ Phrase 4: As the beast's energy blasts tore through the Excelsior's hull
#    ➤ Sentiment: neutral (Confidence: 0.49)
#    ➤ Emotion:   neutral (Confidence: 0.38)
#
# ✂️ Phrase 5: threatened to consume the ship
#    ➤ Sentiment: negative (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 6: Dr. Simmons managed to complete the construction of the weapon
#    ➤ Sentiment: positive (Confidence: 0.53)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 7: activate its destructive power.
#    ➤ Sentiment: negative (Confidence: 0.78)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
#
# 📄 Paragraph 18:
# With a final, desperate lunge, Captain Reynolds plunged his ship into the heart of the Shadowbeast, detonating the weapon and unleashing a cataclysmic explosion that tore the beast apart and severed the Enigma's connection to the cosmic rift.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.72)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.53)
#
# ✂️ Phrase 1: With a final
#    ➤ Sentiment: neutral (Confidence: 0.77)
#    ➤ Emotion:   neutral (Confidence: 0.86)
#
# ✂️ Phrase 2: desperate lunge
#    ➤ Sentiment: negative (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 3: Captain Reynolds plunged his ship into the heart of the Shadowbeast
#    ➤ Sentiment: neutral (Confidence: 0.55)
#    ➤ Emotion:   neutral (Confidence: 0.23)
#
# ✂️ Phrase 4: detonating the weapon
#    ➤ Sentiment: neutral (Confidence: 0.76)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 5: unleashing a cataclysmic explosion that tore the beast apart
#    ➤ Sentiment: negative (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.33)
#
# ✂️ Phrase 6: severed the Enigma's connection to the cosmic rift.
#    ➤ Sentiment: neutral (Confidence: 0.90)
#    ➤ Emotion:   neutral (Confidence: 0.39)
#
#
# 📄 Paragraph 19:
# As the dust settled and the Enigma's forces crumbled under the weight of their own despair, the crew of the Excelsior emerged victorious. They had managed to save the galaxy from the Enigma's tyrannical rule, and in doing so, had fulfilled the prophecy that had guided their journey.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.46)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.60)
#
# ✂️ Phrase 1: As the dust settled
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.84)
#
# ✂️ Phrase 2: the Enigma's forces crumbled under the weight of their own despair
#    ➤ Sentiment: negative (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.41)
#
# ✂️ Phrase 3: the crew of the Excelsior emerged victorious.
#    ➤ Sentiment: positive (Confidence: 0.86)
#    ➤ Emotion:   annoyance (Confidence: 0.27)
#
# ✂️ Phrase 4: They had managed to save the galaxy from the Enigma's tyrannical rule
#    ➤ Sentiment: neutral (Confidence: 0.66)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 5: in doing
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.97)
#
# ✂️ Phrase 6: had fulfilled the prophecy that had guided their journey.
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.29)
#
#
# 📄 Paragraph 20:
# The heroes of the Excelsior returned to Earth, their names etched in the annals of history as the saviors of the galaxy. Their incredible adventure had not only uncovered the secrets of the cosmic rifts but had also revealed the true power of the human spirit, the indomitable will to survive and the unbreakable bonds that forged the greatest heroes the galaxy had ever known.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.95)
# 🎭 Overall Paragraph Emotion ➤ admiration (Confidence: 0.35)
#
# ✂️ Phrase 1: The heroes of the Excelsior returned to Earth
#    ➤ Sentiment: positive (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.33)
#
# ✂️ Phrase 2: their names etched in the annals of history as the saviors of the galaxy.
#    ➤ Sentiment: positive (Confidence: 0.67)
#    ➤ Emotion:   neutral (Confidence: 0.79)
#
# ✂️ Phrase 3: Their incredible adventure had not only uncovered the secrets of the cosmic rifts
#    ➤ Sentiment: positive (Confidence: 0.96)
#    ➤ Emotion:   admiration (Confidence: 0.31)
#
# ✂️ Phrase 4: had also revealed the true power of the human spirit
#    ➤ Sentiment: positive (Confidence: 0.59)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 5: the indomitable will to survive
#    ➤ Sentiment: positive (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.79)
#
# ✂️ Phrase 6: the unbreakable bonds that forged the greatest heroes the galaxy had ever known.
#    ➤ Sentiment: positive (Confidence: 0.94)
#    ➤ Emotion:   admiration (Confidence: 0.82)
#
#
# 📄 Paragraph 21:
# And so, the SS Excelsior and its crew, led by the indomitable Captain Reynolds, sailed onward into the stars, their journey far from over. For they knew that there were still countless mysteries to uncover and challenges to face in the vast expanse of the cosmos. And as long as there were heroes to answer the call, the universe would remain a place of hope, wonder, and boundless possibilities.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.85)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.44)
#
# ✂️ Phrase 1: the SS Excelsior
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.49)
#
# ✂️ Phrase 2: its crew
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 3: led by the indomitable Captain Reynolds
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 4: sailed onward into the stars
#    ➤ Sentiment: positive (Confidence: 0.59)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
# ✂️ Phrase 5: their journey far from over.
#    ➤ Sentiment: neutral (Confidence: 0.60)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 6: For they knew that there were still countless mysteries to uncover
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 7: challenges to face in the vast expanse of the cosmos.
#    ➤ Sentiment: neutral (Confidence: 0.82)
#    ➤ Emotion:   neutral (Confidence: 0.39)
#
# ✂️ Phrase 8: as long as there were heroes to answer the call
#    ➤ Sentiment: neutral (Confidence: 0.50)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
# ✂️ Phrase 9: the universe would remain a place of hope
#    ➤ Sentiment: positive (Confidence: 0.62)
#    ➤ Emotion:   optimism (Confidence: 0.81)
#
# ✂️ Phrase 10: wonder
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   surprise (Confidence: 0.57)
#
# ✂️ Phrase 11: boundless possibilities.
#    ➤ Sentiment: positive (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.58)
#
#
# 📄 Paragraph 22:
# The story begins with a young boy named Thorn, who had just turned twelve. Thorn lived with his grandfather in a small cottage near the edge of Eldoria. His parents had vanished under mysterious circumstances when he was a baby, and his grandfather was all he had left in the world.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.87)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.88)
#
# ✂️ Phrase 1: The story begins with a young boy named Thorn
#    ➤ Sentiment: neutral (Confidence: 0.92)
#    ➤ Emotion:   neutral (Confidence: 0.84)
#
# ✂️ Phrase 2: who had just turned twelve.
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.81)
#
# ✂️ Phrase 3: Thorn lived with his grandfather in a small cottage near the edge of Eldoria.
#    ➤ Sentiment: neutral (Confidence: 0.94)
#    ➤ Emotion:   neutral (Confidence: 0.58)
#
# ✂️ Phrase 4: His parents had vanished under mysterious circumstances when he was a baby
#    ➤ Sentiment: neutral (Confidence: 0.55)
#    ➤ Emotion:   neutral (Confidence: 0.43)
#
# ✂️ Phrase 5: his grandfather was all he had left in the world.
#    ➤ Sentiment: neutral (Confidence: 0.74)
#    ➤ Emotion:   neutral (Confidence: 0.61)
#
#
# 📄 Paragraph 23:
# Thorn's grandfather was a wise and knowledgeable man, a former adventurer who had once explored the depths of Eldoria. He had passed down many tales of the forest to Thorn, filling his head with stories of brave heroes and fearsome beasts. Thorn's favorite of these tales was about the legendary Sword of Eldoria, a weapon of unimaginable power that could grant its wielder the ability to control the very elements of nature.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.72)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.76)
#
# ✂️ Phrase 1: Thorn's grandfather was a wise
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.22)
#
# ✂️ Phrase 2: knowledgeable man
#    ➤ Sentiment: neutral (Confidence: 0.55)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 3: a former adventurer who had once explored the depths of Eldoria.
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.81)
#
# ✂️ Phrase 4: He had passed down many tales of the forest to Thorn
#    ➤ Sentiment: neutral (Confidence: 0.82)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 5: filling his head with stories of brave heroes
#    ➤ Sentiment: positive (Confidence: 0.56)
#    ➤ Emotion:   admiration (Confidence: 0.53)
#
# ✂️ Phrase 6: fearsome beasts.
#    ➤ Sentiment: negative (Confidence: 0.60)
#    ➤ Emotion:   neutral (Confidence: 0.47)
#
# ✂️ Phrase 7: Thorn's favorite of these tales was about the legendary Sword of Eldoria
#    ➤ Sentiment: positive (Confidence: 0.72)
#    ➤ Emotion:   admiration (Confidence: 0.64)
#
# ✂️ Phrase 8: a weapon of unimaginable power that could grant its wielder the ability to control the very elements of nature.
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   neutral (Confidence: 0.43)
#
#
# 📄 Paragraph 24:
# One day, while exploring the forest with his grandfather, Thorn stumbled upon a hidden cave. Inside the cave, he discovered an ancient scroll that spoke of the Sword of Eldoria and its whereabouts. The scroll revealed that the sword was hidden deep within the forest, guarded by a fearsome creature called the Shadow Beast.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.89)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.83)
#
# ✂️ Phrase 1: One day
#    ➤ Sentiment: positive (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 2: while exploring the forest with his grandfather
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.30)
#
# ✂️ Phrase 3: Thorn stumbled upon a hidden cave.
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.73)
#
# ✂️ Phrase 4: Inside the cave
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 5: he discovered an ancient scroll that spoke of the Sword of Eldoria
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.50)
#
# ✂️ Phrase 6: its whereabouts.
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.68)
#
# ✂️ Phrase 7: The scroll revealed that the sword was hidden deep within the forest
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.30)
#
# ✂️ Phrase 8: guarded by a fearsome creature called the Shadow Beast.
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
#
# 📄 Paragraph 25:
# Thorn's heart swelled with excitement and determination as he read the scroll. He knew that he must find the Sword of Eldoria and use its power to protect Eldoria from the evil forces that threatened to destroy it. His grandfather, seeing the determination in his eyes, agreed to help him on his quest.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.91)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.79)
#
# ✂️ Phrase 1: Thorn's heart swelled with excitement
#    ➤ Sentiment: positive (Confidence: 0.95)
#    ➤ Emotion:   neutral (Confidence: 0.42)
#
# ✂️ Phrase 2: determination as he read the scroll.
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 3: He knew that he must find the Sword of Eldoria
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 4: use its power to protect Eldoria from the evil forces that threatened to destroy it.
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   neutral (Confidence: 0.23)
#
# ✂️ Phrase 5: His grandfather
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.63)
#
# ✂️ Phrase 6: seeing the determination in his eyes
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 7: agreed to help him on his quest.
#    ➤ Sentiment: positive (Confidence: 0.56)
#    ➤ Emotion:   approval (Confidence: 0.55)
#
#
# 📄 Paragraph 26:
# And so, the journey began. Thorn and his grandfather traversed through the treacherous terrain of Eldoria, facing many challenges along the way. They encountered a variety of creatures, some friendly and some not so friendly.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.78)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.31)
#
# ✂️ Phrase 1: the journey began.
#    ➤ Sentiment: neutral (Confidence: 0.72)
#    ➤ Emotion:   approval (Confidence: 0.34)
#
# ✂️ Phrase 2: Thorn
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 3: his grandfather traversed through the treacherous terrain of Eldoria
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.37)
#
# ✂️ Phrase 4: facing many challenges along the way.
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 5: They encountered a variety of creatures
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.79)
#
# ✂️ Phrase 6: some friendly
#    ➤ Sentiment: neutral (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.75)
#
# ✂️ Phrase 7: some not
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.65)
#
# ✂️ Phrase 8: friendly.
#    ➤ Sentiment: positive (Confidence: 0.49)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
#
# 📄 Paragraph 27:
# One day, while crossing a rickety bridge over a deep ravine, they encountered a group of goblins. The goblins, who had been tormenting the forest's inhabitants, demanded that Thorn and his grandfather hand over their belongings. Thorn, armed with only his wits and the knowledge passed down by his grandfather, managed to outsmart the goblins and send them fleeing in terror.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.49)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.61)
#
# ✂️ Phrase 1: One day
#    ➤ Sentiment: positive (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 2: while crossing a rickety bridge over a deep ravine
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.74)
#
# ✂️ Phrase 3: they encountered a group of goblins.
#    ➤ Sentiment: neutral (Confidence: 0.86)
#    ➤ Emotion:   neutral (Confidence: 0.58)
#
# ✂️ Phrase 4: The goblins
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 5: who had been tormenting the forest's inhabitants
#    ➤ Sentiment: negative (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.32)
#
# ✂️ Phrase 6: demanded that Thorn
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.89)
#
# ✂️ Phrase 7: his grandfather hand over their belongings.
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.72)
#
# ✂️ Phrase 8: Thorn
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 9: armed with only his wits
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 10: the knowledge passed down by his grandfather
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.34)
#
# ✂️ Phrase 11: managed to outsmart the goblins
#    ➤ Sentiment: neutral (Confidence: 0.51)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 12: send them fleeing in terror.
#    ➤ Sentiment: negative (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
#
# 📄 Paragraph 28:
# As they continued their journey, Thorn and his grandfather found an ally in a wise old owl named Ollivia. Ollivia had lived in Eldoria for centuries and possessed a wealth of knowledge about the forest and its many secrets. She agreed to help them on their quest, providing them with valuable information and guidance.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.59)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.67)
#
# ✂️ Phrase 1: As they continued their journey
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 2: Thorn
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 3: his grandfather found an ally in a wise old owl named Ollivia.
#    ➤ Sentiment: neutral (Confidence: 0.67)
#    ➤ Emotion:   neutral (Confidence: 0.90)
#
# ✂️ Phrase 4: Ollivia had lived in Eldoria for centuries
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 5: possessed a wealth of knowledge about the forest
#    ➤ Sentiment: neutral (Confidence: 0.76)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 6: its many secrets.
#    ➤ Sentiment: neutral (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 7: She agreed to help them on their quest
#    ➤ Sentiment: neutral (Confidence: 0.54)
#    ➤ Emotion:   approval (Confidence: 0.53)
#
# ✂️ Phrase 8: providing them with valuable information
#    ➤ Sentiment: positive (Confidence: 0.53)
#    ➤ Emotion:   neutral (Confidence: 0.40)
#
# ✂️ Phrase 9: guidance.
#    ➤ Sentiment: neutral (Confidence: 0.78)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
#
# 📄 Paragraph 29:
# With Ollivia's help, Thorn and his grandfather discovered the entrance to the Shadow Beast's lair, hidden deep within a dense thicket. As they approached the lair, they were met with a series of riddles and puzzles that they had to solve in order to proceed.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.89)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.87)
#
# ✂️ Phrase 1: With Ollivia's help
#    ➤ Sentiment: neutral (Confidence: 0.76)
#    ➤ Emotion:   neutral (Confidence: 0.67)
#
# ✂️ Phrase 2: Thorn
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 3: his grandfather discovered the entrance to the Shadow Beast's lair
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.51)
#
# ✂️ Phrase 4: hidden deep within a dense thicket.
#    ➤ Sentiment: negative (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 5: As they approached the lair
#    ➤ Sentiment: neutral (Confidence: 0.86)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 6: they were met with a series of riddles
#    ➤ Sentiment: neutral (Confidence: 0.84)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 7: puzzles that they had to solve in order to proceed.
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
#
# 📄 Paragraph 30:
# Thorn's intellect and problem-solving skills were put to the test as he navigated through the lair, solving each riddle and puzzle that stood in their way. Along the way, he also had to face a variety of traps and obstacles, which he managed to overcome with his quick thinking and agility.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.52)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.80)
#
# ✂️ Phrase 1: Thorn's intellect
#    ➤ Sentiment: neutral (Confidence: 0.51)
#    ➤ Emotion:   neutral (Confidence: 0.62)
#
# ...
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
# ✂️ Phrase 10: courage
#    ➤ Sentiment: positive (Confidence: 0.55)
#    ➤ Emotion:   neutral (Confidence: 0.65)
#
# ✂️ Phrase 11: Thorn defeated the sorceress
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.28)
#
# ✂️ Phrase 12: restored peace to Eldoria
#    ➤ Sentiment: neutral (Confidence: 0.49)
#    ➤ Emotion:   neutral (Confidence: 0.53)
#
# ✂️ Phrase 13: proving that the spirit of the hero would never fade.
#    ➤ Sentiment: positive (Confidence: 0.76)
#    ➤ Emotion:   admiration (Confidence: 0.27)
#
#
# 📄 Paragraph 41:
# Our hero, Johnathan, was a young detective who had recently moved to Whispering Shadows, hoping to escape the chaos of the city and find some solace in the calm, idyllic town. He was a tall, lanky man in his late twenties, with dark hair and piercing blue eyes. Johnathan was well-respected among the townspeople, who admired his unwavering dedication to justice and his uncanny ability to solve even the most confounding mysteries.
#
# 📊 Overall Paragraph Sentiment ➤ positive (Confidence: 0.77)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.34)
#
# ✂️ Phrase 1: Our hero
#    ➤ Sentiment: positive (Confidence: 0.86)
#    ➤ Emotion:   neutral (Confidence: 0.40)
#
# ✂️ Phrase 2: Johnathan
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 3: was a young detective who had recently moved to Whispering Shadows
#    ➤ Sentiment: neutral (Confidence: 0.93)
#    ➤ Emotion:   neutral (Confidence: 0.45)
#
# ✂️ Phrase 4: hoping to escape the chaos of the city
#    ➤ Sentiment: neutral (Confidence: 0.53)
#    ➤ Emotion:   optimism (Confidence: 0.81)
#
# ✂️ Phrase 5: find some solace in the calm
#    ➤ Sentiment: positive (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.50)
#
# ✂️ Phrase 6: idyllic town.
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.56)
#
# ✂️ Phrase 7: He was a tall
#    ➤ Sentiment: neutral (Confidence: 0.63)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 8: lanky man in his late twenties
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.86)
#
# ✂️ Phrase 9: with dark hair
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 10: piercing blue eyes.
#    ➤ Sentiment: neutral (Confidence: 0.83)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 11: Johnathan was well-respected among the townspeople
#    ➤ Sentiment: positive (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.65)
#
# ✂️ Phrase 12: who admired his unwavering dedication to justice
#    ➤ Sentiment: positive (Confidence: 0.58)
#    ➤ Emotion:   annoyance (Confidence: 0.32)
#
# ✂️ Phrase 13: his uncanny ability to solve even the most confounding mysteries.
#    ➤ Sentiment: positive (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
#
# 📄 Paragraph 42:
# As Johnathan settled into his new life, he quickly became aware of a series of strange occurrences that had been plaguing the town for years. The townsfolk whispered about these events in hushed tones, their voices barely above a whisper, as if the very shadows around them held a sinister secret.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.77)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.91)
#
# ✂️ Phrase 1: As Johnathan settled into his new life
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.80)
#
# ✂️ Phrase 2: he quickly became aware of a series of strange occurrences that had been plaguing the town for years.
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.49)
#
# ✂️ Phrase 3: The townsfolk whispered about these events in hushed tones
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 4: their voices barely above a whisper
#    ➤ Sentiment: neutral (Confidence: 0.63)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
# ✂️ Phrase 5: as if the very shadows around them held a sinister secret.
#    ➤ Sentiment: neutral (Confidence: 0.63)
#    ➤ Emotion:   neutral (Confidence: 0.75)
#
#
# 📄 Paragraph 43:
# One day, while strolling through the town square, Johnathan overheard two elderly ladies discussing a mysterious figure they had seen late at night. The figure, they said, seemed to vanish into thin air. Intrigued by the tale, Johnathan decided to investigate this enigmatic character.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.91)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.92)
#
# ✂️ Phrase 1: One day
#    ➤ Sentiment: positive (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.66)
#
# ✂️ Phrase 2: while strolling through the town square
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.79)
#
# ✂️ Phrase 3: Johnathan overheard two elderly ladies discussing a mysterious figure they had seen late at night.
#    ➤ Sentiment: neutral (Confidence: 0.95)
#    ➤ Emotion:   neutral (Confidence: 0.57)
#
# ✂️ Phrase 4: The figure
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 5: they said
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 6: seemed to vanish into thin air.
#    ➤ Sentiment: negative (Confidence: 0.62)
#    ➤ Emotion:   neutral (Confidence: 0.90)
#
# ✂️ Phrase 7: Intrigued by the tale
#    ➤ Sentiment: positive (Confidence: 0.82)
#    ➤ Emotion:   neutral (Confidence: 0.94)
#
# ✂️ Phrase 8: Johnathan decided to investigate this enigmatic character.
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.69)
#
#
# 📄 Paragraph 44:
# As night fell, Johnathan ventured into the darkest corners of the town, keeping a sharp eye out for any signs of the elusive figure. Hours passed, and the night seemed to grow more ominous with each passing minute. The wind howled through the narrow streets, and the shadows seemed to take on a life of their own, creeping along the walls and floor like a thousand invisible fingers.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.61)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.81)
#
# ✂️ Phrase 1: As night fell
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.85)
#
# ✂️ Phrase 2: Johnathan ventured into the darkest corners of the town
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.70)
#
# ✂️ Phrase 3: keeping a sharp eye out for any signs of the elusive figure.
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 4: Hours passed
#    ➤ Sentiment: neutral (Confidence: 0.78)
#    ➤ Emotion:   neutral (Confidence: 0.30)
#
# ✂️ Phrase 5: the night seemed to grow more ominous with each passing minute.
#    ➤ Sentiment: negative (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.38)
#
# ✂️ Phrase 6: The wind howled through the narrow streets
#    ➤ Sentiment: neutral (Confidence: 0.54)
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
# ✂️ Phrase 7: the shadows seemed to take on a life of their own
#    ➤ Sentiment: neutral (Confidence: 0.78)
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
# ✂️ Phrase 8: creeping along the walls
#    ➤ Sentiment: neutral (Confidence: 0.70)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 9: floor like a thousand invisible fingers.
#    ➤ Sentiment: neutral (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.83)
#
#
# 📄 Paragraph 45:
# Just as Johnathan was about to give up on his quest, he spotted a figure standing at the edge of the town square. The figure was dressed all in black, with a hood that concealed their face. As Johnathan approached, the figure began to walk away, their footsteps barely audible as they disappeared into the night.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.77)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.94)
#
# ✂️ Phrase 1: Just as Johnathan was about to give up on his quest
#    ➤ Sentiment: negative (Confidence: 0.52)
#    ➤ Emotion:   neutral (Confidence: 0.91)
#
# ✂️ Phrase 2: he spotted a figure standing at the edge of the town square.
#    ➤ Sentiment: neutral (Confidence: 0.93)
#    ➤ Emotion:   neutral (Confidence: 0.64)
#
# ✂️ Phrase 3: The figure was dressed all in black
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.81)
#
# ✂️ Phrase 4: with a hood that concealed their face.
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.78)
#
# ✂️ Phrase 5: As Johnathan approached
#    ➤ Sentiment: neutral (Confidence: 0.90)
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
# ✂️ Phrase 6: the figure began to walk away
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.87)
#
# ✂️ Phrase 7: their footsteps barely audible as they disappeared into the night.
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.52)
#
#
# 📄 Paragraph 46:
# Determined to uncover the truth about this mysterious figure, Johnathan decided to follow them. As he trailed the figure through the darkened streets, he noticed that they seemed to have an uncanny ability to stay just out of reach, always remaining one step ahead.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.80)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.82)
#
# ✂️ Phrase 1: Determined to uncover the truth about this mysterious figure
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.42)
#
# ✂️ Phrase 2: Johnathan decided to follow them.
#    ➤ Sentiment: neutral (Confidence: 0.91)
#    ➤ Emotion:   neutral (Confidence: 0.90)
#
# ✂️ Phrase 3: As he trailed the figure through the darkened streets
#    ➤ Sentiment: neutral (Confidence: 0.85)
#    ➤ Emotion:   neutral (Confidence: 0.84)
#
# ✂️ Phrase 4: he noticed that they seemed to have an uncanny ability to stay just out of reach
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.64)
#
# ✂️ Phrase 5: always remaining one step ahead.
#    ➤ Sentiment: positive (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
#
# 📄 Paragraph 47:
# After hours of relentless pursuit, Johnathan finally cornered the figure in an abandoned warehouse on the outskirts of town. As he entered the warehouse, he found himself in an eerie, dimly lit chamber, with only a single beam of light cutting through the darkness.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.83)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.78)
#
# ✂️ Phrase 1: After hours of relentless pursuit
#    ➤ Sentiment: neutral (Confidence: 0.62)
#    ➤ Emotion:   neutral (Confidence: 0.62)
#
# ✂️ Phrase 2: Johnathan finally cornered the figure in an abandoned warehouse on the outskirts of town.
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.51)
#
# ✂️ Phrase 3: As he entered the warehouse
#    ➤ Sentiment: neutral (Confidence: 0.89)
#    ➤ Emotion:   neutral (Confidence: 0.93)
#
# ✂️ Phrase 4: he found himself in an eerie
#    ➤ Sentiment: neutral (Confidence: 0.66)
#    ➤ Emotion:   neutral (Confidence: 0.77)
#
# ✂️ Phrase 5: dimly lit chamber
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.43)
#
# ✂️ Phrase 6: with only a single beam of light cutting through the darkness.
#    ➤ Sentiment: neutral (Confidence: 0.73)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
#
# 📄 Paragraph 48:
# The figure turned to face Johnathan, their hood falling away to reveal their face. To Johnathan's shock, he found himself looking into the eyes of his long-lost brother, Thomas.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.89)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.53)
#
# ✂️ Phrase 1: The figure turned to face Johnathan
#    ➤ Sentiment: neutral (Confidence: 0.93)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 2: their hood falling away to reveal their face.
#    ➤ Sentiment: neutral (Confidence: 0.87)
#    ➤ Emotion:   neutral (Confidence: 0.82)
#
# ✂️ Phrase 3: To Johnathan's shock
#    ➤ Sentiment: neutral (Confidence: 0.81)
#    ➤ Emotion:   neutral (Confidence: 0.44)
#
# ✂️ Phrase 4: he found himself looking into the eyes of his long-lost brother
#    ➤ Sentiment: neutral (Confidence: 0.88)
#    ➤ Emotion:   neutral (Confidence: 0.51)
#
# ✂️ Phrase 5: Thomas.
#    ➤ Sentiment: neutral (Confidence: 0.79)
#    ➤ Emotion:   neutral (Confidence: 0.30)
#
#
# 📄 Paragraph 49:
# Thomas, it turned out, had been living in Whispering Shadows for years, struggling with a dark secret. As a child, he had been afflicted with a rare and incurable disease that had slowly robbed him of his ability to feel pain. In order to survive, Thomas had taken to stealing medicine from the local pharmacy, using the cover of darkness to slip in and out of the building unnoticed.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.76)
# 🎭 Overall Paragraph Emotion ➤ neutral (Confidence: 0.31)
#
# ✂️ Phrase 1: Thomas
#    ➤ Sentiment: neutral (Confidence: 0.74)
#    ➤ Emotion:   neutral (Confidence: 0.31)
#
# ✂️ Phrase 2: it turned out
#    ➤ Sentiment: neutral (Confidence: 0.66)
#    ➤ Emotion:   neutral (Confidence: 0.68)
#
# ✂️ Phrase 3: had been living in Whispering Shadows for years
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.30)
#
# ✂️ Phrase 4: struggling with a dark secret.
#    ➤ Sentiment: neutral (Confidence: 0.50)
#    ➤ Emotion:   neutral (Confidence: 0.70)
#
# ✂️ Phrase 5: As a child
#    ➤ Sentiment: neutral (Confidence: 0.76)
#    ➤ Emotion:   neutral (Confidence: 0.92)
#
# ✂️ Phrase 6: he had been afflicted with a rare
#    ➤ Sentiment: neutral (Confidence: 0.65)
#    ➤ Emotion:   neutral (Confidence: 0.63)
#
# ✂️ Phrase 7: incurable disease that had slowly robbed him of his ability to feel pain.
#    ➤ Sentiment: negative (Confidence: 0.90)
#    ➤ Emotion:   sadness (Confidence: 0.32)
#
# ✂️ Phrase 8: In order to survive
#    ➤ Sentiment: neutral (Confidence: 0.75)
#    ➤ Emotion:   neutral (Confidence: 0.95)
#
# ✂️ Phrase 9: Thomas had taken to stealing medicine from the local pharmacy
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   neutral (Confidence: 0.25)
#
# ✂️ Phrase 10: using the cover of darkness to slip in
#    ➤ Sentiment: neutral (Confidence: 0.86)
#    ➤ Emotion:   neutral (Confidence: 0.96)
#
# ✂️ Phrase 11: out of the building unnoticed.
#    ➤ Sentiment: neutral (Confidence: 0.80)
#    ➤ Emotion:   neutral (Confidence: 0.72)
#
#
# 📄 Paragraph 50:
# Overwhelmed with guilt, Thomas had withdrawn from the world, becoming a shadowy figure that haunted the town's nighttime landscape. He had hoped that by living a life of secrecy and solitude, he could protect his loved ones from the burden of his condition.
#
# 📊 Overall Paragraph Sentiment ➤ negative (Confidence: 0.70)
# 🎭 Overall Paragraph Emotion ➤ sadness (Confidence: 0.34)
#
# ✂️ Phrase 1: Overwhelmed with guilt
#    ➤ Sentiment: negative (Confidence: 0.75)
#    ➤ Emotion:   neutral (Confidence: 0.26)
#
# ✂️ Phrase 2: Thomas had withdrawn from the world
#    ➤ Sentiment: neutral (Confidence: 0.71)
#    ➤ Emotion:   neutral (Confidence: 0.55)
#
# ✂️ Phrase 3: becoming a shadowy figure that haunted the town's nighttime landscape.
#    ➤ Sentiment: neutral (Confidence: 0.68)
#    ➤ Emotion:   neutral (Confidence: 0.32)
#
# ✂️ Phrase 4: He had hoped that by living a life of secrecy
#    ➤ Sentiment: neutral (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.33)
#
# ✂️ Phrase 5: solitude
#    ➤ Sentiment: neutral (Confidence: 0.61)
#    ➤ Emotion:   neutral (Confidence: 0.88)
#
# ✂️ Phrase 6: he could protect his loved ones from the burden of his condition.
#    ➤ Sentiment: neutral (Confidence: 0.69)
#    ➤ Emotion:   love (Confidence: 0.54)
#
#
# 📄 Paragraph 51:
# Moved by Thomas's plight, Johnathan vowed to help his brother find a cure for his disease. Together, they embarked on a quest that would take them to the farthest reaches of the earth, chasing after every lead and shred of hope.
#
# 📊 Overall Paragraph Sentiment ➤ neutral (Confidence: 0.52)
# 🎭 Overall Paragraph Emotion ➤ optimism (Confidence: 0.31)
#
# ✂️ Phrase 1: Moved by Thomas's plight
#    ➤ Sentiment: neutral (Confidence: 0.58)
#    ➤ Emotion:   neutral (Confidence: 0.35)
